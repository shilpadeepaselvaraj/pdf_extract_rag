# %%
# !pip install PyPDF2 langchain sentence-transformers chromadb torch transformers openai pypdf faiss-cpu tiktoken
# Out:
# Collecting PyPDF2
#   Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Collecting langchain
#   Downloading langchain-0.3.23-py3-none-any.whl (1.0 MB)
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Collecting chromadb
#   Downloading chromadb-1.0.5-cp39-abi3-win_amd64.whl (18.2 MB)
# Collecting torch
#   Downloading torch-2.6.0-cp39-cp39-win_amd64.whl (204.1 MB)
# Collecting transformers
#   Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
# Collecting openai
#   Downloading openai-1.75.0-py3-none-any.whl (646 kB)
# Collecting pypdf
#   Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp39-cp39-win_amd64.whl (13.7 MB)
# Collecting tiktoken
#   Downloading tiktoken-0.9.0-cp39-cp39-win_amd64.whl (894 kB)
# Collecting typing_extensions>=3.10.0.0
#   Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Collecting pydantic<3.0.0,>=2.7.4
#   Downloading pydantic-2.11.3-py3-none-any.whl (443 kB)
# Collecting SQLAlchemy<3,>=1.4
#   Downloading sqlalchemy-2.0.40-cp39-cp39-win_amd64.whl (2.1 MB)
# Collecting PyYAML>=5.3
#   Downloading PyYAML-6.0.2-cp39-cp39-win_amd64.whl (162 kB)
# Collecting requests<3,>=2
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8
#   Downloading langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting langchain-core<1.0.0,>=0.3.51
#   Downloading langchain_core-0.3.54-py3-none-any.whl (433 kB)
# Collecting langsmith<0.4,>=0.1.17
#   Downloading langsmith-0.3.32-py3-none-any.whl (358 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0
#   Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting packaging<25,>=23.2
#   Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Collecting jsonpatch<2.0,>=1.33
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Collecting zstandard<0.24.0,>=0.23.0
#   Downloading zstandard-0.23.0-cp39-cp39-win_amd64.whl (495 kB)
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting orjson<4.0.0,>=3.9.14
#   Downloading orjson-3.10.16-cp39-cp39-win_amd64.whl (133 kB)
# Collecting idna
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
# Collecting certifi
#   Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.8-py3-none-any.whl (78 kB)
# Collecting anyio
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.33.1
#   Downloading pydantic_core-2.33.1-cp39-cp39-win_amd64.whl (2.0 MB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp39-cp39-win_amd64.whl (102 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Collecting greenlet>=1
#   Downloading greenlet-3.2.0-cp39-cp39-win_amd64.whl (294 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting huggingface-hub>=0.20.0
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Collecting Pillow
#   Downloading pillow-11.2.1-cp39-cp39-win_amd64.whl (2.7 MB)
# Collecting scipy
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting networkx
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Collecting filelock
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting fsspec
#   Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Collecting sympy==1.13.1
#   Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting tokenizers<0.22,>=0.21
#   Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
# Requirement already satisfied: numpy>=1.17 in d:\30 ml projects challeng\envprojects\lib\site-packages (from transformers) (2.0.2)
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Collecting regex!=2019.12.17
#   Downloading regex-2024.11.6-cp39-cp39-win_amd64.whl (274 kB)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.32.1-py3-none-any.whl (65 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.32.1-py3-none-any.whl (18 kB)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.53b1-py3-none-any.whl (12 kB)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
# Collecting typer>=0.9.0
#   Downloading typer-0.15.2-py3-none-any.whl (45 kB)
# Collecting posthog>=2.4.0
#   Downloading posthog-3.25.0-py2.py3-none-any.whl (89 kB)
# Collecting chroma-hnswlib==0.7.6
#   Downloading chroma_hnswlib-0.7.6-cp39-cp39-win_amd64.whl (151 kB)
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.71.0-cp39-cp39-win_amd64.whl (4.3 MB)
# Collecting rich>=10.11.0
#   Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the 'd:\30 ml projects challeng\envprojects\scripts\python.exe -m pip install --upgrade pip' command.
# Collecting fastapi==0.115.9
#   Downloading fastapi-0.115.9-py3-none-any.whl (94 kB)
# Collecting importlib-resources
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting build>=1.0.3
#   Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.19.2-cp39-cp39-win_amd64.whl (11.1 MB)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.32.1-py3-none-any.whl (118 kB)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.1.0-cp39-cp39-win_amd64.whl (41 kB)
# Collecting jsonschema>=4.19.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Collecting starlette<0.46.0,>=0.40.0
#   Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
# Collecting importlib-metadata>=4.6
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Collecting zipp>=3.20
#   Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.24.0-cp39-cp39-win_amd64.whl (234 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\30 ml projects challeng\envprojects\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Collecting google-auth>=1.0.1
#   Downloading google_auth-2.39.0-py2.py3-none-any.whl (212 kB)
# Requirement already satisfied: six>=1.9.0 in d:\30 ml projects challeng\envprojects\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting oauthlib>=3.2.2
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Collecting flatbuffers
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting protobuf
#   Downloading protobuf-6.30.2-cp39-cp39-win_amd64.whl (431 kB)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.17.2-cp39-cp39-win_amd64.whl (38 kB)
# Collecting opentelemetry-proto==1.32.1
#   Downloading opentelemetry_proto-1.32.1-py3-none-any.whl (55 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.32.1
#   Downloading opentelemetry_exporter_otlp_proto_common-1.32.1-py3-none-any.whl (18 kB)
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Collecting protobuf
#   Downloading protobuf-5.29.4-cp39-cp39-win_amd64.whl (434 kB)
# Collecting opentelemetry-util-http==0.53b1
#   Downloading opentelemetry_util_http-0.53b1-py3-none-any.whl (7.3 kB)
# Collecting opentelemetry-semantic-conventions==0.53b1
#   Downloading opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl (188 kB)
# Collecting opentelemetry-instrumentation-asgi==0.53b1
#   Downloading opentelemetry_instrumentation_asgi-0.53b1-py3-none-any.whl (16 kB)
# Collecting opentelemetry-instrumentation==0.53b1
#   Downloading opentelemetry_instrumentation-0.53b1-py3-none-any.whl (30 kB)
# Collecting asgiref~=3.0
#   Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting distro>=1.5.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting click>=8.0.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting httptools>=0.6.3
#   Downloading httptools-0.6.4-cp39-cp39-win_amd64.whl (89 kB)
# Collecting websockets>=10.4
#   Downloading websockets-15.0.1-cp39-cp39-win_amd64.whl (176 kB)
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.0.5-cp39-cp39-win_amd64.whl (292 kB)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.9.0-cp39-cp39-win_amd64.whl (208 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-3.0.2-cp39-cp39-win_amd64.whl (15 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (PEP 517): started
#   Building wheel for pypika (PEP 517): finished with status 'done'
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53914 sha256=96401d83057c6925171f135b3b59aec2b1f9f5e6105664d2a4bf02f3f2d572d4
#   Stored in directory: c:\users\shilp\appdata\local\pip\cache\wheels\f7\02\64\d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: zipp, wrapt, urllib3, typing-extensions, sniffio, importlib-metadata, idna, h11, exceptiongroup, deprecated, charset-normalizer, certifi, typing-inspection, requests, pydantic-core, opentelemetry-api, httpcore, colorama, anyio, annotated-types, zstandard, tqdm, rpds-py, requests-toolbelt, PyYAML, pyreadline3, pydantic, pyasn1, protobuf, packaging, orjson, opentelemetry-semantic-conventions, mdurl, jsonpointer, httpx, fsspec, filelock, attrs, tenacity, rsa, referencing, pygments, pyasn1-modules, opentelemetry-util-http, opentelemetry-proto, opentelemetry-instrumentation, oauthlib, mpmath, MarkupSafe, markdown-it-py, langsmith, jsonpatch, humanfriendly, huggingface-hub, click, cachetools, asgiref, websockets, websocket-client, watchfiles, uvicorn, tomli, tokenizers, threadpoolctl, sympy, starlette, shellingham, scipy, safetensors, rich, requests-oauthlib, regex, python-dotenv, pyproject-hooks, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-common, networkx, monotonic, langchain-core, jsonschema-specifications, joblib, jinja2, httptools, grpcio, greenlet, googleapis-common-protos, google-auth, flatbuffers, durationpy, distro, coloredlogs, backoff, typer, transformers, torch, SQLAlchemy, scikit-learn, pypika, posthog, Pillow, overrides, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, onnxruntime, mmh3, langchain-text-splitters, kubernetes, jsonschema, jiter, importlib-resources, fastapi, chroma-hnswlib, build, bcrypt, async-timeout, tiktoken, sentence-transformers, PyPDF2, pypdf, openai, langchain, faiss-cpu, chromadb
# Successfully installed MarkupSafe-3.0.2 Pillow-11.2.1 PyPDF2-3.0.1 PyYAML-6.0.2 SQLAlchemy-2.0.40 annotated-types-0.7.0 anyio-4.9.0 asgiref-3.8.1 async-timeout-4.0.3 attrs-25.3.0 backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 cachetools-5.5.2 certifi-2025.1.31 charset-normalizer-3.4.1 chroma-hnswlib-0.7.6 chromadb-1.0.5 click-8.1.8 colorama-0.4.6 coloredlogs-15.0.1 deprecated-1.2.18 distro-1.9.0 durationpy-0.9 exceptiongroup-1.2.2 faiss-cpu-1.10.0 fastapi-0.115.9 filelock-3.18.0 flatbuffers-25.2.10 fsspec-2025.3.2 google-auth-2.39.0 googleapis-common-protos-1.70.0 greenlet-3.2.0 grpcio-1.71.0 h11-0.14.0 httpcore-1.0.8 httptools-0.6.4 httpx-0.28.1 huggingface-hub-0.30.2 humanfriendly-10.0 idna-3.10 importlib-metadata-8.6.1 importlib-resources-6.5.2 jinja2-3.1.6 jiter-0.9.0 joblib-1.4.2 jsonpatch-1.33 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 kubernetes-32.0.1 langchain-0.3.23 langchain-core-0.3.54 langchain-text-splitters-0.3.8 langsmith-0.3.32 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-5.1.0 monotonic-1.6 mpmath-1.3.0 networkx-3.2.1 oauthlib-3.2.2 onnxruntime-1.19.2 openai-1.75.0 opentelemetry-api-1.32.1 opentelemetry-exporter-otlp-proto-common-1.32.1 opentelemetry-exporter-otlp-proto-grpc-1.32.1 opentelemetry-instrumentation-0.53b1 opentelemetry-instrumentation-asgi-0.53b1 opentelemetry-instrumentation-fastapi-0.53b1 opentelemetry-proto-1.32.1 opentelemetry-sdk-1.32.1 opentelemetry-semantic-conventions-0.53b1 opentelemetry-util-http-0.53b1 orjson-3.10.16 overrides-7.7.0 packaging-24.2 posthog-3.25.0 protobuf-5.29.4 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.11.3 pydantic-core-2.33.1 pygments-2.19.1 pypdf-5.4.0 pypika-0.48.9 pyproject-hooks-1.2.0 pyreadline3-3.5.4 python-dotenv-1.1.0 referencing-0.36.2 regex-2024.11.6 requests-2.32.3 requests-oauthlib-2.0.0 requests-toolbelt-1.0.0 rich-14.0.0 rpds-py-0.24.0 rsa-4.9.1 safetensors-0.5.3 scikit-learn-1.6.1 scipy-1.13.1 sentence-transformers-4.1.0 shellingham-1.5.4 sniffio-1.3.1 starlette-0.45.3 sympy-1.13.1 tenacity-9.1.2 threadpoolctl-3.6.0 tiktoken-0.9.0 tokenizers-0.21.1 tomli-2.2.1 torch-2.6.0 tqdm-4.67.1 transformers-4.51.3 typer-0.15.2 typing-extensions-4.13.2 typing-inspection-0.4.0 urllib3-2.4.0 uvicorn-0.34.2 watchfiles-1.0.5 websocket-client-1.8.0 websockets-15.0.1 wrapt-1.17.2 zipp-3.21.0 zstandard-0.23.0

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in d:\30 ml projects challeng\envprojects\lib\site-packages (4.1.0)
# Requirement already satisfied: tqdm in d:\30 ml projects challeng\envprojects\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in d:\30 ml projects challeng\envprojects\lib\site-packages (from sentence-transformers) (0.30.2)
# Requirement already satisfied: scipy in d:\30 ml projects challeng\envprojects\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: scikit-learn in d:\30 ml projects challeng\envprojects\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: Pillow in d:\30 ml projects challeng\envprojects\lib\site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in d:\30 ml projects challeng\envprojects\lib\site-packages (from sentence-transformers) (4.51.3)
# Requirement already satisfied: torch>=1.11.0 in d:\30 ml projects challeng\envprojects\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\30 ml projects challeng\envprojects\lib\site-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\30 ml projects challeng\envprojects\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: requests in d:\30 ml projects challeng\envprojects\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: packaging>=20.9 in d:\30 ml projects challeng\envprojects\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\30 ml projects challeng\envprojects\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: filelock in d:\30 ml projects challeng\envprojects\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: networkx in d:\30 ml projects challeng\envprojects\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: sympy==1.13.1 in d:\30 ml projects challeng\envprojects\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: jinja2 in d:\30 ml projects challeng\envprojects\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\30 ml projects challeng\envprojects\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in d:\30 ml projects challeng\envprojects\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: safetensors>=0.4.3 in d:\30 ml projects challeng\envprojects\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: numpy>=1.17 in d:\30 ml projects challeng\envprojects\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\30 ml projects challeng\envprojects\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: regex!=2019.12.17 in d:\30 ml projects challeng\envprojects\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\30 ml projects challeng\envprojects\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\30 ml projects challeng\envprojects\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\30 ml projects challeng\envprojects\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\30 ml projects challeng\envprojects\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\30 ml projects challeng\envprojects\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)
# Requirement already satisfied: joblib>=1.2.0 in d:\30 ml projects challeng\envprojects\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\30 ml projects challeng\envprojects\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the 'd:\30 ml projects challeng\envprojects\scripts\python.exe -m pip install --upgrade pip' command.

# %%
#Import Libraries
import os
#import PyPDF2
import re
import numpy as np
import pandas as pd
from tqdm import tqdm
import torch
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.utils import embedding_functions
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
from langchain.document_loaders import PyPDFLoader
import openai
from IPython.display import display, Markdown
import warnings
warnings.filterwarnings('ignore')

print("Libraries imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [8], in <module>
#       7 from tqdm import tqdm
#       8 import torch
# ----> 9 from sentence_transformers import SentenceTransformer
#      10 import chromadb
#      11 from chromadb.utils import embedding_functions
#
# ModuleNotFoundError: No module named 'sentence_transformers'
